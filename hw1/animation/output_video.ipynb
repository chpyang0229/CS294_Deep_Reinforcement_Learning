# %%
import gym
from gym import wrappers
env = gym.make('CartPole-v0')
env = wrappers.Monitor(env, '/home/salmon/deepRL/hw1/animation')
for i_episode in range(10):
    observation = env.reset()
    for t in range(100):
        env.render()
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
# Out:
# [2017-02-18 20:41:24,934] Making new env: CartPole-v0
# [2017-02-18 20:41:24,937] DEPRECATION WARNING: env.spec.timestep_limit has been deprecated. Replace your call to `env.spec.timestep_limit` with `env.spec.tags.get('wrapper_config.TimeLimit.max_episode_steps')`. This change was made 12/28/2016 and is included in version 0.7.0
# [2017-02-18 20:41:24,939] Starting new video recorder writing to /home/salmon/deepRL/hw1/animation/openaigym.video.5.18078.video000000.mp4
# Exception ignored in: <bound method Env.__del__ of <_Monitor<TimeLimit<CartPoleEnv instance>>>>
# Traceback (most recent call last):
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/core.py", line 252, in __del__
#     self.close()
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/core.py", line 190, in close
#     self._close()
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/wrappers/monitoring.py", line 38, in _close
#     self._monitor.close()
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 193, in close
#     self._flush(force=True)
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 183, in _flush
#     'env_info': self._env_info(),
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 300, in _env_info
#     if self.env.spec:
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 98, in env
#     raise error.Error("env has been garbage collected. To keep using a monitor, you must keep around a reference to the env object. (HINT: try assigning the env to a variable in your code.)")
# gym.error.Error: env has been garbage collected. To keep using a monitor, you must keep around a reference to the env object. (HINT: try assigning the env to a variable in your code.)
# Exception ignored in: <bound method MonitorManager.__del__ of <gym.monitoring.monitor_manager.MonitorManager object at 0x7f2e6427f4e0>>
# Traceback (most recent call last):
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 306, in __del__
#     self.close()
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 193, in close
#     self._flush(force=True)
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 183, in _flush
#     'env_info': self._env_info(),
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 300, in _env_info
#     if self.env.spec:
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 98, in env
#     raise error.Error("env has been garbage collected. To keep using a monitor, you must keep around a reference to the env object. (HINT: try assigning the env to a variable in your code.)")
# gym.error.Error: env has been garbage collected. To keep using a monitor, you must keep around a reference to the env object. (HINT: try assigning the env to a variable in your code.)
# Exception ignored in: <bound method Env.__del__ of <_Monitor<TimeLimit<CartPoleEnv instance>>>>
# Traceback (most recent call last):
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/core.py", line 252, in __del__
#     self.close()
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/core.py", line 190, in close
#     self._close()
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/wrappers/monitoring.py", line 38, in _close
#     self._monitor.close()
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 193, in close
#     self._flush(force=True)
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 183, in _flush
#     'env_info': self._env_info(),
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 300, in _env_info
#     if self.env.spec:
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 98, in env
#     raise error.Error("env has been garbage collected. To keep using a monitor, you must keep around a reference to the env object. (HINT: try assigning the env to a variable in your code.)")
# gym.error.Error: env has been garbage collected. To keep using a monitor, you must keep around a reference to the env object. (HINT: try assigning the env to a variable in your code.)
# Exception ignored in: <bound method MonitorManager.__del__ of <gym.monitoring.monitor_manager.MonitorManager object at 0x7f2e6301ceb8>>
# Traceback (most recent call last):
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 306, in __del__
#     self.close()
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 193, in close
#     self._flush(force=True)
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 183, in _flush
#     'env_info': self._env_info(),
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 300, in _env_info
#     if self.env.spec:
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 98, in env
#     raise error.Error("env has been garbage collected. To keep using a monitor, you must keep around a reference to the env object. (HINT: try assigning the env to a variable in your code.)")
# gym.error.Error: env has been garbage collected. To keep using a monitor, you must keep around a reference to the env object. (HINT: try assigning the env to a variable in your code.)
# Exception ignored in: <bound method Env.__del__ of <_Monitor<TimeLimit<CartPoleEnv instance>>>>
# Traceback (most recent call last):
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/core.py", line 252, in __del__
#     self.close()
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/core.py", line 190, in close
#     self._close()
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/wrappers/monitoring.py", line 38, in _close
#     self._monitor.close()
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 193, in close
#     self._flush(force=True)
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 183, in _flush
#     'env_info': self._env_info(),
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 300, in _env_info
#     if self.env.spec:
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 98, in env
#     raise error.Error("env has been garbage collected. To keep using a monitor, you must keep around a reference to the env object. (HINT: try assigning the env to a variable in your code.)")
# gym.error.Error: env has been garbage collected. To keep using a monitor, you must keep around a reference to the env object. (HINT: try assigning the env to a variable in your code.)
# Exception ignored in: <bound method MonitorManager.__del__ of <gym.monitoring.monitor_manager.MonitorManager object at 0x7f2e62faf6d8>>
# Traceback (most recent call last):
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 306, in __del__
#     self.close()
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 193, in close
#     self._flush(force=True)
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 183, in _flush
#     'env_info': self._env_info(),
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 300, in _env_info
#     if self.env.spec:
#   File "/home/salmon/anaconda3/lib/python3.6/site-packages/gym/monitoring/monitor_manager.py", line 98, in env
#     raise error.Error("env has been garbage collected. To keep using a monitor, you must keep around a reference to the env object. (HINT: try assigning the env to a variable in your code.)")
# gym.error.Error: env has been garbage collected. To keep using a monitor, you must keep around a reference to the env object. (HINT: try assigning the env to a variable in your code.)
# [ 0.02154216  0.02488031  0.0112258   0.02499706]
# [ 0.02203977 -0.17040082  0.01172574  0.32120061]
# [ 0.01863175 -0.36568777  0.01814975  0.61755819]
# [ 0.01131799 -0.170824    0.03050092  0.33064641]
# [ 0.00790151 -0.36636655  0.03711385  0.63278969]
# [ 0.00057418 -0.17178148  0.04976964  0.35202205]
# [-0.00286145 -0.36757455  0.05681008  0.65997423]
# [-0.01021294 -0.56343916  0.07000956  0.96999035]
# [-0.02148172 -0.36932326  0.08940937  0.70009579]
# [-0.02886819 -0.56556347  0.10341129  1.01953167]
# [-0.04017945 -0.37196031  0.12380192  0.76102708]
# [-0.04761866 -0.56855056  0.13902246  1.08996035]
# [-0.05898967 -0.37550743  0.16082167  0.84393047]
# [-0.06649982 -0.57241553  0.17770028  1.18255931]
# [2017-02-18 20:41:25,526] Starting new video recorder writing to /home/salmon/deepRL/hw1/animation/openaigym.video.5.18078.video000001.mp4
# [-0.07794813 -0.76934125  0.20135146  1.5252657 ]
# Episode finished after 15 timesteps
# [ 0.03586031 -0.02544435 -0.0006371   0.04184892]
# [  3.53514214e-02   1.69686728e-01   1.99882753e-04  -2.51034945e-01]
# [ 0.03874516 -0.02543808 -0.00482082  0.04171102]
# [ 0.03823639  0.16975267 -0.0039866  -0.25248901]
# [ 0.04163145 -0.02531213 -0.00903638  0.03893381]
# [ 0.04112521 -0.22030334 -0.0082577   0.32875202]
# [ 0.03671914 -0.41530677 -0.00168266  0.61881946]
# [ 0.028413   -0.22016135  0.01069373  0.32560705]
# [ 0.02400978 -0.02519328  0.01720587  0.03631555]
# [ 0.02350591  0.16967776  0.01793218 -0.25088947]
# [ 0.02689947 -0.02569561  0.01291439  0.04739525]
# [ 0.02638555 -0.22100034  0.0138623   0.34412464]
# [ 0.02196555 -0.41631672  0.02074479  0.64114645]
# [ 0.01363921 -0.22149001  0.03356772  0.3550678 ]
# [ 0.00920941 -0.41707276  0.04066908  0.65814371]
# [ 0.00086796 -0.22253977  0.05383195  0.37853892]
# [-0.00358284 -0.028222    0.06140273  0.10330344]
# [-0.00414728  0.16596869  0.0634688  -0.16939259]
# [-0.0008279   0.36012747  0.06008095 -0.44139706]
# [ 0.00637464  0.55435002  0.051253   -0.71455206]
# [ 0.01746165  0.35855744  0.03696196 -0.40618705]
# [ 0.02463279  0.16293137  0.02883822 -0.10208403]
# [ 0.02789142 -0.03259174  0.02679654  0.19955596]
# [ 0.02723959 -0.2280865   0.03078766  0.50057006]
# [ 0.02267786 -0.03341178  0.04079906  0.21774651]
# [ 0.02200962  0.16110391  0.04515399 -0.06179262]
# [ 0.0252317   0.35555034  0.04391814 -0.33989422]
# [ 0.03234271  0.1598319   0.03712025 -0.03369186]
# [ 0.03553934 -0.03580216  0.03644642  0.27046793]
# [ 0.0348233   0.15878125  0.04185578 -0.01050048]
# [-0.0503398   0.02309973 -0.19515222 -1.15469375]
# Episode finished after 29 timesteps
# [ 0.02450405 -0.0104228  -0.0414118   0.02928927]
# [ 0.02429559 -0.20492717 -0.04082601  0.30862409]
# [ 0.02019705 -0.00924801 -0.03465353  0.00335042]
# [ 0.02001209  0.18635335 -0.03458652 -0.30006156]
# [ 0.02373915 -0.00825899 -0.04058775 -0.01848405]
# [ 0.02357397 -0.20277607 -0.04095743  0.26112175]
# [ 0.01951845 -0.39729015 -0.035735    0.54061006]
# [ 0.01157265 -0.59189205 -0.0249228   0.82182271]
# [ -2.65191002e-04  -3.96438123e-01  -8.48634361e-03   5.21406316e-01]
# [-0.00819395 -0.20119775  0.00194178  0.22606135]
# [-0.01221791 -0.0061036   0.00646301 -0.06600844]
# [-0.01233998 -0.20131762  0.00514284  0.22870658]
# [-0.01636633 -0.00626954  0.00971697 -0.06234968]
# [-0.01649172 -0.20152945  0.00846998  0.2333831 ]
# [-0.02052231 -0.00652954  0.01313764 -0.05661613]
# [-0.0206529  -0.20183737  0.01200532  0.2401827 ]
# [-0.02468965 -0.00688896  0.01680897 -0.04868937]
# [-0.02482743  0.18798798  0.01583518 -0.33602189]
# [-0.02106767 -0.0073557   0.00911475 -0.03838775]
# [-0.02121478 -0.20260716  0.00834699  0.25715698]
# [-0.02526693 -0.39784728  0.01349013  0.55246095]
# [-0.03322387 -0.20291736  0.02453935  0.26405864]
# [-0.03728222 -0.00815411  0.02982052 -0.02078444]
# [-0.0374453  -0.20369074  0.02940483  0.28115605]
# [-0.04151912 -0.39921952  0.03502796  0.58296621]
# [-0.04950351 -0.59481425  0.04668728  0.88647444]
# [-0.06139979 -0.79053782  0.06441677  1.19346097]
# [-0.07721055 -0.59630659  0.08828599  0.92164381]
# [-0.08913668 -0.79250344  0.10671886  1.24071529]
# [-0.10498675 -0.98882136  0.13153317  1.56483269]
# [-0.12476318 -0.79549411  0.16282982  1.31590611]
# [-0.14067306 -0.60276306  0.18914795  1.07829427]
# Episode finished after 32 timesteps
# [-0.00483779  0.00499435 -0.00411104 -0.02998389]
# [-0.00473791  0.20017501 -0.00471072 -0.32396105]
# [-0.0007344   0.00512046 -0.01118994 -0.0327674 ]
# [-0.000632    0.20040107 -0.01184529 -0.32895977]
# [ 0.00337603  0.39568963 -0.01842448 -0.62535449]
# [ 0.01128982  0.20082967 -0.03093157 -0.33853064]
# [ 0.01530641  0.39637779 -0.03770219 -0.64080496]
# [ 0.02323397  0.20180116 -0.05051829 -0.36022924]
# [ 0.02726999  0.00743236 -0.05772287 -0.08389405]
# [ 0.02741864  0.2033322  -0.05940075 -0.3942155 ]
# [ 0.03148528  0.39924452 -0.06728506 -0.70501924]
# [ 0.03947017  0.20511623 -0.08138545 -0.4342526 ]
# [ 0.0435725   0.4012904  -0.0900705  -0.75144077]
# [ 0.0515983   0.59753139 -0.10509931 -1.07105396]
# [2017-02-18 20:41:29,217] Starting new video recorder writing to /home/salmon/deepRL/hw1/animation/openaigym.video.5.18078.video000008.mp4
# [ 0.06354893  0.79387403 -0.12652039 -1.39478518]
# [ 0.07942641  0.60053302 -0.1544161  -1.14418958]
# [ 0.09143707  0.79729747 -0.17729989 -1.48104258]
# [ 0.10738302  0.99408386 -0.20692074 -1.82344828]
# Episode finished after 18 timesteps
# [-0.02612183  0.01404903 -0.00671604 -0.02788828]
# [-0.02584085  0.20926664 -0.0072738  -0.3226826 ]
# [-0.02165552  0.01424902 -0.01372745 -0.03230238]
# [-0.02137054 -0.18067341 -0.0143735   0.25601797]
# [-0.024984   -0.37558722 -0.00925314  0.54413283]
# [-0.03249575 -0.57057793  0.00162951  0.83388598]
# [-0.04390731 -0.37547828  0.01830723  0.54171597]
# [-0.05141687 -0.5708527   0.02914155  0.84011051]
# [-0.06283393 -0.76636013  0.04594376  1.14181356]
# [-0.07816113 -0.96205144  0.06878004  1.44854348]
# [-0.09740216 -0.76783922  0.0977509   1.17811934]
# [-0.11275894 -0.96408522  0.12131329  1.4997761 ]
# [-0.13204065 -1.16045397  0.15130881  1.82774312]
# [-0.15524973 -1.35689511  0.18786368  2.16335345]
# Episode finished after 14 timesteps
# [ 0.01378945  0.03063341 -0.00106889  0.02666089]
# [ 0.01440212 -0.1644732  -0.00053567  0.31900637]
# [ 0.01111266 -0.35958751  0.00584446  0.61152032]
# [ 0.00392091 -0.55479066  0.01807487  0.90603831]
# [-0.00717491 -0.75015263  0.03619563  1.20434711]
# [-0.02217796 -0.94572328  0.06028257  1.50815013]
# [-0.04109243 -1.14152199  0.09044558  1.81902706]
# [-0.06392287 -1.33752542  0.12682612  2.13838525]
# [-0.09067337 -1.53365293  0.16959382  2.46740067]
# Episode finished after 9 timesteps

# %%
from moviepy.editor import *
# Out:
# ---------------------------------------------------------------------------
# NeedDownloadError                         Traceback (most recent call last)
# /home/salmon/anaconda3/lib/python3.6/site-packages/imageio/plugins/ffmpeg.py in get_exe()
#      81             exe = get_remote_file('ffmpeg/' + FNAME_PER_PLATFORM[plat],
# ---> 82                                   auto=False)
#      83             os.chmod(exe, os.stat(exe).st_mode | stat.S_IEXEC)  # executable
#
# /home/salmon/anaconda3/lib/python3.6/site-packages/imageio/core/fetching.py in get_remote_file(fname, directory, force_download, auto)
#     101     if not auto:
# --> 102         raise NeedDownloadError()
#     103
#
# NeedDownloadError:
#
# During handling of the above exception, another exception occurred:
#
# NeedDownloadError                         Traceback (most recent call last)
# <ipython-input-21-099f6ff01130> in <module>()
# ----> 1 from moviepy.editor import *
#       2
#
# /home/salmon/anaconda3/lib/python3.6/site-packages/moviepy/editor.py in <module>()
#      20 # Clips
#      21
# ---> 22 from .video.io.VideoFileClip import VideoFileClip
#      23 from .video.io.ImageSequenceClip import ImageSequenceClip
#      24 from .video.io.downloader import download_webfile
#
# /home/salmon/anaconda3/lib/python3.6/site-packages/moviepy/video/io/VideoFileClip.py in <module>()
#       1 import os
#       2
# ----> 3 from moviepy.video.VideoClip import VideoClip
#       4 from moviepy.audio.io.AudioFileClip import AudioFileClip
#       5 from moviepy.Clip import Clip
#
# /home/salmon/anaconda3/lib/python3.6/site-packages/moviepy/video/VideoClip.py in <module>()
#      18
#      19 import moviepy.audio.io as aio
# ---> 20 from .io.ffmpeg_writer import ffmpeg_write_image, ffmpeg_write_video
#      21 from .io.ffmpeg_tools import ffmpeg_merge_video_audio
#      22 from .io.gif_writers import (write_gif,
#
# /home/salmon/anaconda3/lib/python3.6/site-packages/moviepy/video/io/ffmpeg_writer.py in <module>()
#      17     DEVNULL = open(os.devnull, 'wb')
#      18
# ---> 19 from moviepy.config import get_setting
#      20 from moviepy.tools import verbose_print
#      21
#
# /home/salmon/anaconda3/lib/python3.6/site-packages/moviepy/config.py in <module>()
#      36 if FFMPEG_BINARY=='ffmpeg-imageio':
#      37     from imageio.plugins.ffmpeg import get_exe
# ---> 38     FFMPEG_BINARY = get_exe()
#      39
#      40 elif FFMPEG_BINARY=='auto-detect':
#
# /home/salmon/anaconda3/lib/python3.6/site-packages/imageio/plugins/ffmpeg.py in get_exe()
#      84             return exe
#      85         except NeedDownloadError:
# ---> 86             raise NeedDownloadError('Need ffmpeg exe. '
#      87                                     'You can download it by calling:\n'
#      88                                     '  imageio.plugins.ffmpeg.download()')
#
# NeedDownloadError: Need ffmpeg exe. You can download it by calling:
#   imageio.plugins.ffmpeg.download()

# %%
from moviepy.editor import VideoClip
# Out:
# ---------------------------------------------------------------------------
# NeedDownloadError                         Traceback (most recent call last)
# /home/salmon/anaconda3/lib/python3.6/site-packages/imageio/plugins/ffmpeg.py in get_exe()
#      81             exe = get_remote_file('ffmpeg/' + FNAME_PER_PLATFORM[plat],
# ---> 82                                   auto=False)
#      83             os.chmod(exe, os.stat(exe).st_mode | stat.S_IEXEC)  # executable
#
# /home/salmon/anaconda3/lib/python3.6/site-packages/imageio/core/fetching.py in get_remote_file(fname, directory, force_download, auto)
#     101     if not auto:
# --> 102         raise NeedDownloadError()
#     103
#
# NeedDownloadError:
#
# During handling of the above exception, another exception occurred:
#
# NeedDownloadError                         Traceback (most recent call last)
# <ipython-input-22-7f13869ff4fc> in <module>()
# ----> 1 from moviepy.editor import VideoClip
#
# /home/salmon/anaconda3/lib/python3.6/site-packages/moviepy/editor.py in <module>()
#      20 # Clips
#      21
# ---> 22 from .video.io.VideoFileClip import VideoFileClip
#      23 from .video.io.ImageSequenceClip import ImageSequenceClip
#      24 from .video.io.downloader import download_webfile
#
# /home/salmon/anaconda3/lib/python3.6/site-packages/moviepy/video/io/VideoFileClip.py in <module>()
#       1 import os
#       2
# ----> 3 from moviepy.video.VideoClip import VideoClip
#       4 from moviepy.audio.io.AudioFileClip import AudioFileClip
#       5 from moviepy.Clip import Clip
#
# /home/salmon/anaconda3/lib/python3.6/site-packages/moviepy/video/VideoClip.py in <module>()
#      18
#      19 import moviepy.audio.io as aio
# ---> 20 from .io.ffmpeg_writer import ffmpeg_write_image, ffmpeg_write_video
#      21 from .io.ffmpeg_tools import ffmpeg_merge_video_audio
#      22 from .io.gif_writers import (write_gif,
#
# /home/salmon/anaconda3/lib/python3.6/site-packages/moviepy/video/io/ffmpeg_writer.py in <module>()
#      17     DEVNULL = open(os.devnull, 'wb')
#      18
# ---> 19 from moviepy.config import get_setting
#      20 from moviepy.tools import verbose_print
#      21
#
# /home/salmon/anaconda3/lib/python3.6/site-packages/moviepy/config.py in <module>()
#      36 if FFMPEG_BINARY=='ffmpeg-imageio':
#      37     from imageio.plugins.ffmpeg import get_exe
# ---> 38     FFMPEG_BINARY = get_exe()
#      39
#      40 elif FFMPEG_BINARY=='auto-detect':
#
# /home/salmon/anaconda3/lib/python3.6/site-packages/imageio/plugins/ffmpeg.py in get_exe()
#      84             return exe
#      85         except NeedDownloadError:
# ---> 86             raise NeedDownloadError('Need ffmpeg exe. '
#      87                                     'You can download it by calling:\n'
#      88                                     '  imageio.plugins.ffmpeg.download()')
#
# NeedDownloadError: Need ffmpeg exe. You can download it by calling:
#   imageio.plugins.ffmpeg.download()
